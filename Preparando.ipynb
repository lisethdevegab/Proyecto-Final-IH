# %%
import pandas as pd
import numpy as np
import re

# %%
train1 = pd.read_csv('missingdead.csv', encoding='utf8')

train1.head(2)
# Out:
#    Web ID Region of Incident  Reported day Reported Month  Reported Year  \
# 0   52491      Mediterranean            14            Oct           2019
# 1   52496             Europe            14            Oct           2019
#
#    Number Dead  Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0            2                                    6                       2
# 1            2                                    6                       2
#
#    Number of Survivors  Number of Females  ...  Number of Children  \
# 0                   33                  1  ...                   2
# 1                   14                  1  ...                   1
#
#    Cause of Death                               Location Description  \
# 0        Drowning  Off the coast of Altınova, Ayvalık, Balıkesir ...
# 1        Drowning  Bodies recovered on Le Touquet, Pas-de-Calais,...
#
#                 Information Source Source Quality        Migration Route  \
# ...

# %%
df2 = train1.copy()

# %%
#Eliminamos columnas innecesarias
df2.drop(columns=['Web ID', 'URL'], inplace=True)

df2.dtypes
# Out:
# Region of Incident                             object
# Reported day                                    int64
# Reported Month                                  int64
# Reported Year                                   int64
# Number Dead                                     int64
# Minimum Estimated Number of Missing             int64
# Total Dead and Missing                          int64
# Number of Survivors                             int64
# Number of Females                               int64
# Number of Males                                 int64
# Number of Children                              int64
# Cause of Death                                 object
# Location Description                           object
# Information Source                             object
# Source Quality                                  int64
# Migration Route                                object
# UNSD Geographical Grouping                     object
# ...

# %%
#Reordenamos las columnas

df2 = df2[['Reported case', 'Reported day','Reported Month','Reported Year',
          'Region of Incident', 'Number Dead',
       'Minimum Estimated Number of Missing', 'Total Dead and Missing',
       'Number of Survivors', 'Number of Females', 'Number of Males',
       'Number of Children', 'Cause of Death', 'Location Description',
       'Information Source', 'Source Quality', 'Migration Route',
       'UNSD Geographical Grouping', 'Latitude', 'Length']]

df2.head(2)
# Out:
#   Reported case  Reported day  Reported Month  Reported Year  \
# 0    2019-10-14            14              10           2019
# 1    2019-10-14            14              10           2019
#
#   Region of Incident  Number Dead  Minimum Estimated Number of Missing  \
# 0       Mediterranea            2                                    6
# 1             Europe            2                                    6
#
#    Total Dead and Missing  Number of Survivors  Number of Females  \
# 0                       2                   33                  1
# 1                       2                   14                  1
#
#    Number of Males  Number of Children Cause of Death  \
# 0                1                   2       Drowning
# 1                2                   1       Drowning
#
#                                 Location Description  \
# 0  Off the coast of Altınova, Ayvalık, Balıkesir ...
# 1  Bodies recovered on Le Touquet, Pas-de-Calais,...
#
# ...

# %%
#Obtenemos un csv para entrenar

df2.to_csv('region2.csv', index=False)


df2.head()
# Out:
#   Reported case  Reported day  Reported Month  Reported Year  \
# 0    2019-10-14            14              10           2019
# 1    2019-10-14            14              10           2019
# 2    2019-12-10            12              10           2019
# 3    2019-11-10            11              10           2019
# 4    2019-09-10             9              10           2019
#
#   Region of Incident  Number Dead  Minimum Estimated Number of Missing  \
# 0       Mediterranea            2                                    6
# 1             Europe            2                                    6
# 2   US-Mexico Border            1                                    6
# 3    Central America            3                                    6
# 4             Europe            3                                    6
#
#    Total Dead and Missing  Number of Survivors  Number of Females  \
# 0                       2                   33                  1
# ...
